# %%
import subprocess, sys
result = subprocess.run(
    [sys.executable, "-m", "pytest", "tests/", "--tb=line", "--no-header", "-q"],
    cwd="/workspaces/OPENQANT",
    capture_output=True, text=True,
)
print(result.stdout[-4000:])
print("Exit:", result.returncode)
# Out:
# ============================= test session starts ==============================
# collected 46 items
#
# tests/integration/test_e2e_backtest.py ....                              [  8%]
# tests/unit/test_risk_and_data.py ..F...................                  [ 56%]
# tests/unit/test_strategies.py ..F.................                       [100%]
#
# =================================== FAILURES ===================================
# ______ TestRiskManagerPositionSizing.test_low_confidence_reduces_position ______
# tests/unit/test_risk_and_data.py:80: in test_low_confidence_reduces_position
#     assert rm._calc_position_size(sig_low, market) < rm._calc_position_size(sig_high, market)
# E   AssertionError: assert 200.0 < 200.0
# ...
